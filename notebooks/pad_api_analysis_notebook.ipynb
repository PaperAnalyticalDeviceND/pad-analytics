# %% [markdown]
# # Paper analytical devices (PADs) API
# ## About
# PADs are test cards that can quickly determine whether a drug tablet contains the correct medicines. They are cheap and easy to use. They don't require power, chemicals, solvents, or any expensive instruments, so they can be deployed rapidly at large scale wherever a problem with pharmaceutical quality is suspected. More information can be found here https://padproject.nd.edu.
#
# ## The PADS projects provides an API
# The PAD project provides an API to access previously collected data from PAD cards.
#
# To use the API please request an API key from the team.
#
# This Jupyter Notebook provides examples of accessing data via the API.

# %%
# # If you are using Google Colaboratory then run this box and the next one
# # link Collab to Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# Change into our folder so we can access libraries
# %cd /content/drive/MyDrive/Colab\ Notebooks/user_api_example
# !ls -l

# %%
import sys, os

# import files in the src folder wich is ../src/*
sys.path.append(os.path.abspath('../src'))

# %%
# PAD API database query notebook
# Chris Sweet 06/15/22
# 
# Inports and defines
# importing the helper library
import pad_helper 


# set url for pad server
pad_url = 'https://pad.crc.nd.edu/'

# you need to ask Chris nicely for an API key
API_KEY = '5NWT4K7IS60WMLR3J2LV'

# %%
# Load the data into pandas if successful
import pandas as pd

# lets grab some data, in the example we download all records for project "FHI2022"
my_data = pad_helper.query_pad_database("FHI2020", API_KEY)

# check if we were succesful
if my_data and 'status' in my_data:
    if my_data['status'] == 'ko':
        print("Error:", my_data['error_description'])
    else:
        # if succesful we can create a pandas table
        if 'data' in my_data:
            df = pd.DataFrame(my_data['data'])
            if 'headers' in my_data:
                df.columns = my_data['headers']
            print("Data loaded!")
            #print(my_data)
        else:
            print("Empty query!")
# Out:
# Data loaded!

# %%
df
# Out:
#          id                      sample_name           test_name  \
# 0     15194                      Chloroquine  12LanePADKenya2015
# 1     15195                      Chloroquine  12LanePADKenya2015
# 2     15204                      doxycycline  12LanePADKenya2015
# 3     15205                        isoniazid  12LanePADKenya2015
# 4     15206                        isoniazid  12LanePADKenya2015
# ...     ...                              ...                 ...
# 9701  25852                      ceftriaxone  12LanePADKenya2015
# 9702  31166                      amoxicillin  12LanePADKenya2015
# 9703  48814  Doxorubicin (powder or tablets)  12LanePADKenya2015
# 9704  49179                    Ciprofloxacin  12LanePADKenya2015
# 9705  49217                    Ciprofloxacin  12LanePADKenya2015
#
#                      user_name     date_of_creation  \
# 0              Marya Lieberman  2020-05-17T10:45:22
# 1              Marya Lieberman  2020-05-17T10:50:05
# 2              Marya Lieberman  2020-05-17T12:00:04
# 3              Marya Lieberman  2020-05-17T12:00:06
# 4              Marya Lieberman  2020-05-17T12:00:08
# ...                        ...                  ...
# 9701  api-OUDPXFH17PEGKUW3FM4Z  2020-12-17T09:18:58
# 9702  api-OUDPXFH17PEGKUW3FM4Z  2021-07-08T00:43:47
# 9703  api-5NWT4K7IS60WMLR3J2LV  2024-07-20T09:39:20
# 9704  api-5NWT4K7IS60WMLR3J2LV  2024-09-05T12:44:46
# 9705  api-5NWT4K7IS60WMLR3J2LV  2024-09-11T14:54:50
#
#                                      picture_1_location  \
# 0     /var/www/html/joomla/images/padimages/email/ra...
# 1     /var/www/html/joomla/images/padimages/email/ra...
# 2     /var/www/html/joomla/images/padimages/email/ra...
# 3     /var/www/html/joomla/images/padimages/email/ra...
# 4     /var/www/html/joomla/images/padimages/email/ra...
# ...                                                 ...
# 9701  /var/www/html/joomla/images/padimages/api/raw/...
# 9702  /var/www/html/joomla/images/padimages/api/raw/...
# 9703  /var/www/html/images/padimages/raw_local/40000...
# 9704  /var/www/html/images/padimages/raw_local/40000...
# 9705  /var/www/html/images/padimages/raw_local/40000...
#
#                                 processed_file_location      processing_date  \
# 0     /var/www/html/joomla/images/padimages/email/pr...  2020-05-17T10:45:22
# 1     /var/www/html/joomla/images/padimages/email/pr...  2020-05-17T10:50:05
# 2     /var/www/html/joomla/images/padimages/email/pr...  2020-05-17T12:00:04
# 3     /var/www/html/joomla/images/padimages/email/pr...  2020-05-17T12:00:06
# 4     /var/www/html/joomla/images/padimages/email/pr...  2020-05-17T12:00:08
# ...                                                 ...                  ...
# 9701  /var/www/html/joomla/images/padimages/api/proc...  2020-12-17T09:18:58
# 9702  /var/www/html/joomla/images/padimages/api/proc...  2021-07-08T00:43:47
# 9703  /var/www/html/images/padimages/processed/40000...  2024-07-20T09:39:20
# 9704  /var/www/html/images/padimages/processed/40000...  2024-09-05T12:44:46
# 9705  /var/www/html/images/padimages/processed/40000...  2024-09-11T14:54:50
#
#           camera_type_1                                              notes  \
# 0         BLU BLU R1 HD                      emailed rectified pad image.
# 1         BLU BLU R1 HD                      emailed rectified pad image.
# 2         BLU BLU R1 HD  emailed rectified pad image. batch=n/a, quanti...
# 3       Google Pixel 3a  emailed rectified pad image. batch=n/a, quanti...
# 4       Google Pixel 3a  emailed rectified pad image. batch=n/a, quanti...
# ...                 ...                                                ...
# 9701  samsung SM-G770U1                                    batch=4403419,
# 9702     Xiaomi POCO X2                                        batch=n/a,
# 9703             iPhone  {"Safe":"Suspected safe","Prediction score":0,...
# 9704     HUAWEI JSN-L21  {"Phone ID":"e0896db79c1f77c6","Quantity NN":5...
# 9705             iPhone  {"Safe":"Suspected unsafe","Prediction score":...
#
#      category  sample_id  quantity
# 0     FHI2020      50332       100
# 1     FHI2020      50332       100
# 2     FHI2020      50332        50
# 3     FHI2020      50332        20
# 4     FHI2020      50332        20
# ...       ...        ...       ...
# 9701  FHI2020      57410       100
# 9702  FHI2020      57638       100
# 9703  FHI2020      53170       100
# 9704  FHI2020      53170       100
# 9705  FHI2020      53170       100
#
# [9706 rows x 13 columns]

# %%
def standardize_names(name):
    return name.lower().replace(' ', '-')
    
df['sample_name'] = df['sample_name'].apply(standardize_names)

# %%
test_df = pd.read_csv('../data/10_region_rgb__test.csv')

# Filtering results_pls by the 'id' column based on the values present in the 'image' column of test_df
df_test = df[df['id'].isin(test_df['Image'])]
df_test
# Out:
#          id  sample_name           test_name                 user_name  \
# 18    15229  amoxicillin  12LanePADKenya2015           Marya Lieberman
# 22    15233  amoxicillin  12LanePADKenya2015           Marya Lieberman
# 25    15236  amoxicillin  12LanePADKenya2015           Marya Lieberman
# 27    15238  amoxicillin  12LanePADKenya2015           Marya Lieberman
# 37    15253  amoxicillin  12LanePADKenya2015           Marya Lieberman
# ...     ...          ...                 ...                       ...
# 9669  25637         ripe  12LanePADKenya2015  api-OUDPXFH17PEGKUW3FM4Z
# 9670  25638         ripe  12LanePADKenya2015  api-OUDPXFH17PEGKUW3FM4Z
# 9674  25642         ripe  12LanePADKenya2015  api-OUDPXFH17PEGKUW3FM4Z
# 9678  25646         ripe  12LanePADKenya2015  api-OUDPXFH17PEGKUW3FM4Z
# 9683  25834  amoxicillin  12LanePADKenya2015  api-OUDPXFH17PEGKUW3FM4Z
#
#          date_of_creation                                 picture_1_location  \
# 18    2020-05-18T09:50:09  /var/www/html/images/padimages/raw/10000/15229...
# 22    2020-05-18T09:50:19  /var/www/html/images/padimages/raw/10000/15233...
# 25    2020-05-18T09:50:25  /var/www/html/images/padimages/raw/10000/15236...
# 27    2020-05-18T09:50:30  /var/www/html/images/padimages/raw/10000/15238...
# 37    2020-05-18T10:40:18  /var/www/html/images/padimages/raw/10000/15253...
# ...                   ...                                                ...
# 9669  2020-07-10T15:15:03  /var/www/html/images/padimages/raw/20000/25637...
# 9670  2020-07-10T15:15:08  /var/www/html/images/padimages/raw/20000/25638...
# 9674  2020-07-10T15:15:28  /var/www/html/images/padimages/raw/20000/25642...
# 9678  2020-07-10T15:15:47  /var/www/html/images/padimages/raw/20000/25646...
# 9683  2020-10-28T10:07:34  /var/www/html/images/padimages/raw/20000/25834...
#
#                                 processed_file_location      processing_date  \
# 18    /var/www/html/images/padimages/processed/10000...  2020-05-18T09:50:09
# 22    /var/www/html/images/padimages/processed/10000...  2020-05-18T09:50:19
# 25    /var/www/html/images/padimages/processed/10000...  2020-05-18T09:50:25
# 27    /var/www/html/images/padimages/processed/10000...  2020-05-18T09:50:30
# 37    /var/www/html/images/padimages/processed/10000...  2020-05-18T10:40:18
# ...                                                 ...                  ...
# 9669  /var/www/html/images/padimages/processed/20000...  2020-07-10T15:15:03
# 9670  /var/www/html/images/padimages/processed/20000...  2020-07-10T15:15:08
# 9674  /var/www/html/images/padimages/processed/20000...  2020-07-10T15:15:28
# 9678  /var/www/html/images/padimages/processed/20000...  2020-07-10T15:15:47
# 9683  /var/www/html/images/padimages/processed/20000...  2020-10-28T10:07:34
#
#           camera_type_1                                              notes  \
# 18      Google Pixel 3a  emailed rectified pad image. batch=n/a, quanti...
# 22      Google Pixel 3a  emailed rectified pad image. batch=n/a, quanti...
# 25      Google Pixel 3a  emailed rectified pad image. batch=n/a, quanti...
# 27      Google Pixel 3a  emailed rectified pad image. batch=n/a, quanti...
# 37      Google Pixel 3a  emailed rectified pad image. batch=n/a, quanti...
# ...                 ...                                                ...
# 9669   samsung SM-A505F                                       batch=n/a, s
# 9670   samsung SM-A505F                                     batch=n/a, s s
# 9674   samsung SM-A505F                                     batch=n/a, s s
# 9678   samsung SM-A505F                                     batch=n/a, s s
# 9683  samsung SM-G770U1                            batch=n/a, Arqaq's test
#
#      category  sample_id  quantity
# 18    FHI2020      53848       100
# 22    FHI2020      53697       100
# 25    FHI2020      53703       100
# 27    FHI2020      53703       100
# 37    FHI2020      53712        80
# ...       ...        ...       ...
# 9669  FHI2020      55075        50
# 9670  FHI2020      55492        20
# 9674  FHI2020      55075        50
# 9678  FHI2020      55432        80
# 9683  FHI2020      57414       100
#
# [2000 rows x 13 columns]

# %% [markdown]
# ## Neural Network Classification example
# The PAD project uses neural networks to try and classify drugs.
#
# In this example we will download images from the ```FHI2022``` project and predict the drug.
#
# The workflow is
# 1. Grab a Neural Network. These weights/graph files can be generated by training or downloaded from the PADs website.
# 1. Download and loop through the images and run the NN to classify.

# %%
# STAGE 2
import os

# Create a PLS class instance
import pad_analysis
# Out:
# 2024-09-30 04:23:04.418856: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-09-30 04:23:04.469117: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-30 04:23:04.469158: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-30 04:23:04.469186: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-30 04:23:04.478825: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Lets use a Neural Network to catagorize
# first we need the NN 
# If you need one run this to grab from server:
nn_url = 'https://pad.crc.nd.edu/neuralnetworks/tf_lite/24fhiNN1quantityAPI/1.0/24fhiNN1quantityAPI.tflite'

# call helper function
if pad_helper.pad_download(nn_url):
    print(nn_url, "downloaded.")
# Out:
# https://pad.crc.nd.edu/neuralnetworks/tf_lite/24fhiNN1quantityAPI/1.0/24fhiNN1quantityAPI.tflite downloaded.

# %%
# Create a NN class instance
import os
import pad_analysis

nn_file = os.path.basename(nn_url)
print(nn_file)

# creat NN instance
cat_nn = pad_analysis.pad_neural_network(nn_file)
# Out:
# 24fhiNN1quantityAPI.tflite
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
#!pip install requests
import requests
import numpy as np
import tensorflow as tf
from PIL import Image, ImageFile
from io import BytesIO

ImageFile.LOAD_TRUNCATED_IMAGES = True

def read_img(image_url):
  # Get the image data from the URL
  response = requests.get(image_url)
  response.raise_for_status()  # Ensure the request was successful

  # Open the image using PIL directly from the HTTP response
  img = Image.open(BytesIO(response.content))
  return img

def nn_predict(image_url, model_path):
  labels = ['0', '100', '20', '50', '80']

  # Read the image from the URL
  img = read_img(image_url)

  #crop image to get active area
  img = img.crop((71, 359, 71+636, 359+490))

  #for square images
  size = (454, 454)
  img = img.resize((size),Image.BICUBIC)#, Image.ANTIALIAS)

  #reshape the image as numpy
  #im = np.asarray(img).flatten().reshape(1, HEIGHT_INPUT, WIDTH_INPUT, DEPTH)

  HEIGHT_INPUT, WIDTH_INPUT, DEPTH = (454, 454,3)

  #reshape the image as numpy
  im = np.asarray(img).flatten().reshape(1, HEIGHT_INPUT, WIDTH_INPUT, DEPTH).astype(np.float32)

  # Load the TFLite model and allocate tensors.
  # model_file = 'lite_models/' + arch + experiment + '_v1p0'

  interpreter = tf.lite.Interpreter(model_path=model_path)
  interpreter.allocate_tensors()

  # Get input and output tensors.
  input_details = interpreter.get_input_details()
  output_details = interpreter.get_output_details()
  #print("input", input_details[0])

  # Test the model on random input data.
  input_shape = input_details[0]['shape']
  #input_data = np.array(np.random.random_sample(input_shape), dtype=np.float32)
  interpreter.set_tensor(input_details[0]['index'], im)

  # predict
  interpreter.invoke()

  # result
  result = interpreter.get_tensor(output_details[0]['index'])  

  num_label = np.argmax(result[0])
  prediction = labels[num_label]
  # print("Prediction: ", prediction)
  
  probability = tf.nn.softmax(result[0])[num_label].numpy()
  # print("Probability: ", probability)

  # energy
  energy = tf.reduce_logsumexp(result[0], -1)
  # print("Energy: ", energy.numpy())

  return prediction, probability, energy.numpy()

# %%
# Creating the 'results_pls' dataframe by selecting relevant columns from 'df' and adding 'pred_quantity'
results_nn = pd.DataFrame({
    'id': df_test['id'],
    'sample_id': df_test['sample_id'],
    'actual_class': df_test['sample_name'],    # Renaming 'sample_name' to 'actual_class'
    'actual_quantity': df_test['quantity'],    # Renaming 'quantity' to 'actual_quantity'
    'nn_pred_quantity': [None] * len(df_test), # Initializing with None values
    'nn_pred_prob': [None] * len(df_test),     # Initializing with None values
    'nn_pred_energy': [None] * len(df_test)    # Initializing with None values

})

# %%
results_nn
# Out:
#          id  sample_id actual_class  actual_quantity nn_pred_quantity  \
# 18    15229      53848  amoxicillin              100             None
# 22    15233      53697  amoxicillin              100             None
# 25    15236      53703  amoxicillin              100             None
# 27    15238      53703  amoxicillin              100             None
# 37    15253      53712  amoxicillin               80             None
# ...     ...        ...          ...              ...              ...
# 9669  25637      55075         ripe               50             None
# 9670  25638      55492         ripe               20             None
# 9674  25642      55075         ripe               50             None
# 9678  25646      55432         ripe               80             None
# 9683  25834      57414  amoxicillin              100             None
#
#      nn_pred_prob nn_pred_energy
# 18           None           None
# 22           None           None
# 25           None           None
# 27           None           None
# 37           None           None
# ...           ...            ...
# 9669         None           None
# 9670         None           None
# 9674         None           None
# 9678         None           None
# 9683         None           None
#
# [2000 rows x 7 columns]

# %%
# loop over rows and get the first 10 to classify the drug

# define temporary file
#temp_file = './temp.png'

# count the rows so we can break early
row_count = 0

# for pandas we iterate with iterrows
for row in df_test.iterrows():
    
    # update counter
    

    # the data is in the second component of the row for pandas
    row_data = row[1]
    
    # get image location
    image_url = pad_url + str(row_data['processed_file_location'])
    actual_label = row_data['quantity']
    
    print(row_data['id'])
    
    prediction, probability, energy = nn_predict(image_url,  nn_file)

    results_nn.iloc[row_count, 4] = prediction
    results_nn.iloc[row_count, 5] = probability
    results_nn.iloc[row_count, 6] = energy

    print(image_url, actual_label, prediction)
    
    # print("Actual Quantity: ", row_data['quantity'])
    # print("Predicted Quantity: ", prediction)
    # print("Probability: ", probability)
    # print("Energy: ", energy)

    
    row_count += 1

    # break once we have out 10 data points
    # if row_count >= 4:
    #     break

# %%
results_nn.to_csv('../data/results_nn_quantity.csv', index=False)

# %%
results_nn
# Out:
#          id  sample_id actual_class  actual_quantity nn_pred_quantity  \
# 18    15229      53848  amoxicillin              100              100
# 22    15233      53697  amoxicillin              100              100
# 25    15236      53703  amoxicillin              100              100
# 27    15238      53703  amoxicillin              100              100
# 37    15253      53712  amoxicillin               80               80
# ...     ...        ...          ...              ...              ...
# 9669  25637      55075         ripe               50               50
# 9670  25638      55492         ripe               20               20
# 9674  25642      55075         ripe               50               50
# 9678  25646      55432         ripe               80              100
# 9683  25834      57414  amoxicillin              100               20
#
#      nn_pred_prob nn_pred_energy
# 18       0.993513      -4.268341
# 22       0.999912      -1.493712
# 25       0.997775      -1.615417
# 27       0.998222      -2.102292
# 37       0.875029      -6.462397
# ...           ...            ...
# 9669     0.954011      -4.103797
# 9670     0.998589      -1.996377
# 9674     0.994402      -3.224622
# 9678     0.524335      -6.212135
# 9683     0.983061       -3.90811
#
# [2000 rows x 7 columns]

# %%
results_nn_nnan =  results_nn.dropna()
results_nn_nnan
# Out:
#          id  sample_id actual_class  actual_quantity nn_pred_quantity  \
# 18    15229      53848  amoxicillin              100              100
# 22    15233      53697  amoxicillin              100              100
# 25    15236      53703  amoxicillin              100              100
# 27    15238      53703  amoxicillin              100              100
# 37    15253      53712  amoxicillin               80               80
# ...     ...        ...          ...              ...              ...
# 9669  25637      55075         ripe               50               50
# 9670  25638      55492         ripe               20               20
# 9674  25642      55075         ripe               50               50
# 9678  25646      55432         ripe               80              100
# 9683  25834      57414  amoxicillin              100               20
#
#      nn_pred_prob nn_pred_energy
# 18       0.993513      -4.268341
# 22       0.999912      -1.493712
# 25       0.997775      -1.615417
# 27       0.998222      -2.102292
# 37       0.875029      -6.462397
# ...           ...            ...
# 9669     0.954011      -4.103797
# 9670     0.998589      -1.996377
# 9674     0.994402      -3.224622
# 9678     0.524335      -6.212135
# 9683     0.983061       -3.90811
#
# [2000 rows x 7 columns]

# %%
# results_nn_nnan[results_nn_nnan.actual_class=='lactose']

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# Calculate the RMSE between actual_quantity and pred_quantity
rmse = np.sqrt(mean_squared_error(results_nn_nnan['actual_quantity'].astype(int), results_nn_nnan['nn_pred_quantity'].astype(int)))

# Print the RMSE
print(f"RMSE: {rmse}")
# Out:
# RMSE: 18.25239710284652

# %%
# Function to calculate RMSE
def calculate_rmse(group):
    actual = group['actual_quantity'].astype(int)
    predicted = group['nn_pred_quantity'].astype(int)
    return np.sqrt(np.mean((actual - predicted) ** 2))

# %%
# Grouping by 'actual_class' and applying the RMSE calculation
rmse_by_class = results_nn_nnan.groupby('actual_class').apply(calculate_rmse)

# Display the RMSE for each actual_class
rmse_by_class
# Out:
# /tmp/ipykernel_608080/3580415958.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   rmse_by_class = results_nn_nnan.groupby('actual_class').apply(calculate_rmse)
# actual_class
# albendazole                   22.425400
# amoxicillin                   24.513967
# ampicillin                    20.340243
# azithromycin                  22.534997
# benzyl-penicillin             30.884400
# ceftriaxone                   23.279508
# chloroquine                   16.794382
# ciprofloxacin                 20.901800
# doxycycline                   24.614678
# epinephrine                   15.161961
# ethambutol                    17.458743
# ferrous-sulfate                9.412571
# hydroxychloroquine            12.725130
# isoniazid                     15.578284
# lactose                        0.000000
# promethazine-hydrochloride    16.361795
# pyrazinamide                  16.982133
# rifampicin                    19.585876
# ripe                          12.043465
# sulfamethoxazole              14.548212
# tetracycline                  19.483625
# dtype: float64

# %% [markdown]
# ## NN API

# %%
API_LABELS = ['Albendazole','Amoxicillin','Ampicillin','Azithromycin','Benzyl-Penicillin','Blank','Ceftriaxone','Chloroquine','Ciprofloxacin','Doxycycline','Epinephrine', \
    'Ethambutol','Ferrous-Sulfate','Hydroxychloroquine','Isoniazid','Lactose','Promethazine-Hydrochloride','Pyrazinamide','Rifampicin','Ripe','Sulfamethoxazole','Swiped-but-not-run','Tetracycline']

# %%
# Add  a column 'nn_pred_api' and  'nn_pred_api_energy': to 'results_nn_nnan' dataframe
results_nn_nnan['nn_pred_api'] = [None] * len(results_nn_nnan)
results_nn_nnan['nn_pred_api_prob'] = [None] * len(results_nn_nnan)
results_nn_nnan['nn_pred_api_energy'] = [None] * len(results_nn_nnan)

# sorted(results_nn_nnan.actual_class.unique().tolist())

# %%
# Lets use a Neural Network to catagorize
# first we need the NN 
# If you need one run this to grab from server:
nn_url = 'https://pad.crc.nd.edu/neuralnetworks/tf_lite/24fhiNN1classifyAPI/1.0/24fhiNN1classifyAPI.tflite'

# call helper function
if pad_helper.pad_download(nn_url):
    print(nn_url, "downloaded.")
# Out:
# https://pad.crc.nd.edu/neuralnetworks/tf_lite/24fhiNN1classifyAPI/1.0/24fhiNN1classifyAPI.tflite downloaded.

# %%
# Create a NN class instance
import os
import pad_analysis

nn_file = os.path.basename(nn_url)
print(nn_file)

# creat NN instance
# cat_nn = pad_analysis.pad_neural_network(nn_file)
# Out:
# 24fhiNN1classifyAPI.tflite

# %%
import requests
import numpy as np
import tensorflow as tf
from PIL import Image, ImageFile
from io import BytesIO

ImageFile.LOAD_TRUNCATED_IMAGES = True

def read_img(image_url):
  # Get the image data from the URL
  response = requests.get(image_url)
  response.raise_for_status()  # Ensure the request was successful

  # Open the image using PIL directly from the HTTP response
  img = Image.open(BytesIO(response.content))
  return img

def nn_predict(image_url, model_path):
  labels = API_LABELS

  # Read the image from the URL
  img = read_img(image_url)

  #crop image to get active area
  img = img.crop((71, 359, 71+636, 359+490))

  #for square images
  size = (454, 454)
  img = img.resize((size),Image.BICUBIC)#, Image.ANTIALIAS)

  #reshape the image as numpy
  #im = np.asarray(img).flatten().reshape(1, HEIGHT_INPUT, WIDTH_INPUT, DEPTH)

  HEIGHT_INPUT, WIDTH_INPUT, DEPTH = (454, 454,3)

  #reshape the image as numpy
  im = np.asarray(img).flatten().reshape(1, HEIGHT_INPUT, WIDTH_INPUT, DEPTH).astype(np.float32)

  # Load the TFLite model and allocate tensors.
  # model_file = 'lite_models/' + arch + experiment + '_v1p0'

  interpreter = tf.lite.Interpreter(model_path=model_path)
  interpreter.allocate_tensors()

  # Get input and output tensors.
  input_details = interpreter.get_input_details()
  output_details = interpreter.get_output_details()
  #print("input", input_details[0])

  # Test the model on random input data.
  input_shape = input_details[0]['shape']
  #input_data = np.array(np.random.random_sample(input_shape), dtype=np.float32)
  interpreter.set_tensor(input_details[0]['index'], im)

  # predict
  interpreter.invoke()

  # result
  result = interpreter.get_tensor(output_details[0]['index'])  

  num_label = np.argmax(result[0])
  prediction = labels[num_label]
  # print("Prediction: ", prediction)
  
  probability = tf.nn.softmax(result[0])[num_label].numpy()
  # print("Probability: ", probability)

  # energy
  energy = tf.reduce_logsumexp(result[0], -1)
  # print("Energy: ", energy.numpy())

  return prediction, probability, energy.numpy()

# %%
nn_file
# Out:
# '24fhiNN1classifyAPI.tflite'

# %%
row_count = 0

# for pandas we iterate with iterrows
for row in df_test.iterrows():
    
    # update counter
    

    # the data is in the second component of the row for pandas
    row_data = row[1]
    
    # get image location
    image_url = pad_url + str(row_data['processed_file_location'])
    actual_label = row_data['quantity']
    
    print(row_data['id'])
    
    prediction, probability, energy = nn_predict(image_url,  nn_file)

    results_nn_nnan.iloc[row_count, 7] = prediction
    results_nn_nnan.iloc[row_count, 8] = probability
    results_nn_nnan.iloc[row_count, 9] = energy

    print(image_url, actual_label, prediction)
    
    # print("Actual Quantity: ", row_data['quantity'])
    # print("Predicted Quantity: ", prediction)
    # print("Probability: ", probability)
    # print("Energy: ", energy)

    
    row_count += 1

    # break once we have out 10 data points
    # if row_count >= 4:
    #     break
# Out:
# 15229
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15229_processed.png 100 Amoxicillin
# 15233
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15233_processed.png 100 Amoxicillin
# 15236
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15236_processed.png 100 Amoxicillin
# 15238
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15238_processed.png 100 Amoxicillin
# 15253
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15253_processed.png 80 Amoxicillin
# 15261
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15261_processed.png 80 Amoxicillin
# 15265
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15265_processed.png 100 Amoxicillin
# 15266
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15266_processed.png 80 Amoxicillin
# 15268
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15268_processed.png 80 Amoxicillin
# 15278
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15278_processed.png 100 Amoxicillin
# 15281
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15281_processed.png 100 Amoxicillin
# 15285
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15285_processed.png 80 Amoxicillin
# 15286
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15286_processed.png 100 Amoxicillin
# 15287
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15287_processed.png 100 Amoxicillin
# 15289
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15289_processed.png 100 Amoxicillin
# 15292
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15292_processed.png 80 Amoxicillin
# 15294
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15294_processed.png 80 Amoxicillin
# 15297
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15297_processed.png 80 Amoxicillin
# 15302
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15302_processed.png 80 Amoxicillin
# 15310
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15310_processed.png 50 Amoxicillin
# 15311
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15311_processed.png 50 Amoxicillin
# 15312
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15312_processed.png 50 Amoxicillin
# 15315
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15315_processed.png 50 Amoxicillin
# 15316
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15316_processed.png 50 Amoxicillin
# 15320
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15320_processed.png 50 Amoxicillin
# 15321
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15321_processed.png 50 Amoxicillin
# 15322
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15322_processed.png 50 Amoxicillin
# 15326
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15326_processed.png 80 Amoxicillin
# 15327
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15327_processed.png 80 Amoxicillin
# 15328
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15328_processed.png 80 Amoxicillin
# 15329
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15329_processed.png 80 Amoxicillin
# 15330
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15330_processed.png 80 Amoxicillin
# 15336
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15336_processed.png 80 Amoxicillin
# 15337
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15337_processed.png 80 Amoxicillin
# 15345
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15345_processed.png 100 Amoxicillin
# 15348
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15348_processed.png 100 Amoxicillin
# 15349
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15349_processed.png 80 Amoxicillin
# 15352
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15352_processed.png 100 Amoxicillin
# 15357
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15357_processed.png 100 Amoxicillin
# 15364
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15364_processed.png 100 Amoxicillin
# 15373
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15373_processed.png 100 Amoxicillin
# 15379
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15379_processed.png 100 Amoxicillin
# 15382
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15382_processed.png 100 Amoxicillin
# 15400
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15400_processed.png 50 Amoxicillin
# 15403
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15403_processed.png 20 Amoxicillin
# 15405
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15405_processed.png 20 Amoxicillin
# 15413
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15413_processed.png 20 Amoxicillin
# 15415
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15415_processed.png 50 Amoxicillin
# 15416
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15416_processed.png 50 Amoxicillin
# 15425
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15425_processed.png 50 Amoxicillin
# 15427
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15427_processed.png 50 Amoxicillin
# 15433
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15433_processed.png 50 Amoxicillin
# 15434
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15434_processed.png 50 Amoxicillin
# 15441
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15441_processed.png 50 Amoxicillin
# 15447
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15447_processed.png 50 Amoxicillin
# 15450
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15450_processed.png 50 Amoxicillin
# 15452
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15452_processed.png 50 Amoxicillin
# 15456
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15456_processed.png 20 Amoxicillin
# 15462
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15462_processed.png 20 Amoxicillin
# 15463
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15463_processed.png 20 Amoxicillin
# 15464
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15464_processed.png 20 Amoxicillin
# 15472
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15472_processed.png 20 Amoxicillin
# 15476
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15476_processed.png 20 Amoxicillin
# 15482
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15482_processed.png 20 Amoxicillin
# 15483
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15483_processed.png 20 Amoxicillin
# 15484
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15484_processed.png 20 Amoxicillin
# 15488
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15488_processed.png 20 Amoxicillin
# 15493
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15493_processed.png 20 Amoxicillin
# 15494
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15494_processed.png 20 Amoxicillin
# 15495
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15495_processed.png 20 Amoxicillin
# 15498
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15498_processed.png 20 Amoxicillin
# 15499
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15499_processed.png 20 Amoxicillin
# 15500
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15500_processed.png 20 Amoxicillin
# 15506
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15506_processed.png 20 Amoxicillin
# 15509
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15509_processed.png 20 Amoxicillin
# 15515
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15515_processed.png 20 Amoxicillin
# 15517
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15517_processed.png 20 Amoxicillin
# 15525
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15525_processed.png 100 Chloroquine
# 15529
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15529_processed.png 100 Chloroquine
# 15538
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15538_processed.png 100 Chloroquine
# 15544
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15544_processed.png 100 Chloroquine
# 15547
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15547_processed.png 100 Chloroquine
# 15563
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15563_processed.png 100 Chloroquine
# 15564
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15564_processed.png 100 Chloroquine
# 15565
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15565_processed.png 100 Chloroquine
# 15566
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15566_processed.png 100 Chloroquine
# 15570
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15570_processed.png 100 Chloroquine
# 15574
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15574_processed.png 100 Chloroquine
# 15578
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15578_processed.png 100 Chloroquine
# 15579
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15579_processed.png 100 Chloroquine
# 15583
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15583_processed.png 100 Chloroquine
# 15584
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15584_processed.png 100 Chloroquine
# 15588
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15588_processed.png 100 Hydroxychloroquine
# 15593
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15593_processed.png 100 Hydroxychloroquine
# 15594
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15594_processed.png 100 Hydroxychloroquine
# 15596
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15596_processed.png 100 Hydroxychloroquine
# 15598
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15598_processed.png 100 Hydroxychloroquine
# 15600
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15600_processed.png 100 Hydroxychloroquine
# 15601
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15601_processed.png 100 Hydroxychloroquine
# 15613
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15613_processed.png 100 Hydroxychloroquine
# 15616
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15616_processed.png 100 Hydroxychloroquine
# 15619
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15619_processed.png 100 Hydroxychloroquine
# 15622
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15622_processed.png 100 Hydroxychloroquine
# 15624
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15624_processed.png 100 Hydroxychloroquine
# 15626
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15626_processed.png 100 Hydroxychloroquine
# 15630
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15630_processed.png 100 Hydroxychloroquine
# 15645
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15645_processed.png 80 Hydroxychloroquine
# 15646
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15646_processed.png 80 Hydroxychloroquine
# 15649
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15649_processed.png 100 Hydroxychloroquine
# 15650
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15650_processed.png 80 Hydroxychloroquine
# 15652
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15652_processed.png 80 Hydroxychloroquine
# 15667
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15667_processed.png 80 Hydroxychloroquine
# 15668
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15668_processed.png 80 Hydroxychloroquine
# 15671
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15671_processed.png 80 Hydroxychloroquine
# 15672
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15672_processed.png 80 Hydroxychloroquine
# 15673
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15673_processed.png 80 Hydroxychloroquine
# 15683
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15683_processed.png 80 Hydroxychloroquine
# 15687
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15687_processed.png 100 Hydroxychloroquine
# 15688
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15688_processed.png 100 Hydroxychloroquine
# 15696
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15696_processed.png 80 Hydroxychloroquine
# 15702
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15702_processed.png 100 Hydroxychloroquine
# 15706
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15706_processed.png 100 Hydroxychloroquine
# 15712
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15712_processed.png 80 Hydroxychloroquine
# 15717
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15717_processed.png 80 Hydroxychloroquine
# 15726
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15726_processed.png 80 Hydroxychloroquine
# 15741
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15741_processed.png 100 Hydroxychloroquine
# 15743
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15743_processed.png 80 Hydroxychloroquine
# 15744
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15744_processed.png 80 Hydroxychloroquine
# 15753
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15753_processed.png 100 Hydroxychloroquine
# 15768
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15768_processed.png 80 Hydroxychloroquine
# 15777
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15777_processed.png 100 Hydroxychloroquine
# 15779
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15779_processed.png 80 Hydroxychloroquine
# 15780
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15780_processed.png 100 Hydroxychloroquine
# 15786
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15786_processed.png 100 Hydroxychloroquine
# 15791
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15791_processed.png 100 Hydroxychloroquine
# 15793
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15793_processed.png 100 Hydroxychloroquine
# 15815
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15815_processed.png 50 Hydroxychloroquine
# 15817
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15817_processed.png 50 Hydroxychloroquine
# 15818
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15818_processed.png 50 Hydroxychloroquine
# 15823
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15823_processed.png 50 Hydroxychloroquine
# 15829
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15829_processed.png 50 Hydroxychloroquine
# 15832
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15832_processed.png 50 Hydroxychloroquine
# 15836
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15836_processed.png 50 Hydroxychloroquine
# 15839
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15839_processed.png 50 Hydroxychloroquine
# 15842
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15842_processed.png 50 Hydroxychloroquine
# 15863
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15863_processed.png 50 Hydroxychloroquine
# 15864
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15864_processed.png 50 Hydroxychloroquine
# 15867
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15867_processed.png 50 Hydroxychloroquine
# 15869
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15869_processed.png 50 Hydroxychloroquine
# 15872
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15872_processed.png 50 Hydroxychloroquine
# 15873
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15873_processed.png 50 Hydroxychloroquine
# 15874
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15874_processed.png 50 Hydroxychloroquine
# 15885
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15885_processed.png 50 Hydroxychloroquine
# 15889
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15889_processed.png 50 Hydroxychloroquine
# 15903
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15903_processed.png 50 Hydroxychloroquine
# 15904
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15904_processed.png 50 Hydroxychloroquine
# 15905
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15905_processed.png 50 Hydroxychloroquine
# 15906
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15906_processed.png 50 Hydroxychloroquine
# 15907
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15907_processed.png 50 Hydroxychloroquine
# 15911
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15911_processed.png 50 Hydroxychloroquine
# 15912
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15912_processed.png 50 Hydroxychloroquine
# 15916
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15916_processed.png 50 Hydroxychloroquine
# 15919
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15919_processed.png 50 Hydroxychloroquine
# 15923
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15923_processed.png 50 Hydroxychloroquine
# 15924
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15924_processed.png 50 Hydroxychloroquine
# 15927
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15927_processed.png 50 Hydroxychloroquine
# 15928
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15928_processed.png 50 Hydroxychloroquine
# 15929
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15929_processed.png 20 Hydroxychloroquine
# 15938
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15938_processed.png 20 Hydroxychloroquine
# 15939
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15939_processed.png 20 Hydroxychloroquine
# 15940
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15940_processed.png 20 Hydroxychloroquine
# 15956
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15956_processed.png 20 Hydroxychloroquine
# 15958
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15958_processed.png 20 Hydroxychloroquine
# 15959
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15959_processed.png 20 Hydroxychloroquine
# 15972
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15972_processed.png 20 Hydroxychloroquine
# 15981
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15981_processed.png 20 Hydroxychloroquine
# 15982
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15982_processed.png 20 Hydroxychloroquine
# 15983
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15983_processed.png 20 Hydroxychloroquine
# 15985
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15985_processed.png 20 Hydroxychloroquine
# 15991
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15991_processed.png 20 Hydroxychloroquine
# 16003
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16003_processed.png 100 Promethazine-Hydrochloride
# 16007
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16007_processed.png 100 Promethazine-Hydrochloride
# 16014
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16014_processed.png 100 Promethazine-Hydrochloride
# 16015
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16015_processed.png 100 Promethazine-Hydrochloride
# 16016
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16016_processed.png 100 Promethazine-Hydrochloride
# 16024
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16024_processed.png 100 Promethazine-Hydrochloride
# 16030
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16030_processed.png 100 Promethazine-Hydrochloride
# 16037
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16037_processed.png 100 Promethazine-Hydrochloride
# 16039
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16039_processed.png 100 Promethazine-Hydrochloride
# 16040
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16040_processed.png 100 Promethazine-Hydrochloride
# 16047
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16047_processed.png 100 Promethazine-Hydrochloride
# 16051
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16051_processed.png 100 Promethazine-Hydrochloride
# 16052
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16052_processed.png 80 Promethazine-Hydrochloride
# 16054
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16054_processed.png 80 Promethazine-Hydrochloride
# 16055
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16055_processed.png 80 Promethazine-Hydrochloride
# 16057
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16057_processed.png 80 Promethazine-Hydrochloride
# 16069
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16069_processed.png 80 Promethazine-Hydrochloride
# 16074
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16074_processed.png 80 Promethazine-Hydrochloride
# 16075
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16075_processed.png 80 Promethazine-Hydrochloride
# 16089
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16089_processed.png 80 Promethazine-Hydrochloride
# 16092
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16092_processed.png 80 Promethazine-Hydrochloride
# 16093
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16093_processed.png 80 Promethazine-Hydrochloride
# 16094
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16094_processed.png 50 Promethazine-Hydrochloride
# 16098
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16098_processed.png 50 Promethazine-Hydrochloride
# 16105
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16105_processed.png 50 Promethazine-Hydrochloride
# 16107
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16107_processed.png 50 Promethazine-Hydrochloride
# 16111
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16111_processed.png 50 Promethazine-Hydrochloride
# 16112
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16112_processed.png 50 Promethazine-Hydrochloride
# 16113
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16113_processed.png 50 Promethazine-Hydrochloride
# 16119
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16119_processed.png 50 Promethazine-Hydrochloride
# 16122
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16122_processed.png 50 Promethazine-Hydrochloride
# 16123
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16123_processed.png 50 Promethazine-Hydrochloride
# 16124
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16124_processed.png 50 Promethazine-Hydrochloride
# 16127
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16127_processed.png 50 Promethazine-Hydrochloride
# 16135
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16135_processed.png 50 Promethazine-Hydrochloride
# 16138
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16138_processed.png 50 Promethazine-Hydrochloride
# 16143
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16143_processed.png 50 Promethazine-Hydrochloride
# 16147
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16147_processed.png 50 Promethazine-Hydrochloride
# 16148
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16148_processed.png 50 Promethazine-Hydrochloride
# 16149
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16149_processed.png 50 Promethazine-Hydrochloride
# 16151
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16151_processed.png 50 Promethazine-Hydrochloride
# 16159
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16159_processed.png 50 Promethazine-Hydrochloride
# 16164
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16164_processed.png 20 Promethazine-Hydrochloride
# 16167
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16167_processed.png 20 Promethazine-Hydrochloride
# 16172
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16172_processed.png 20 Promethazine-Hydrochloride
# 16175
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16175_processed.png 20 Promethazine-Hydrochloride
# 16180
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16180_processed.png 20 Promethazine-Hydrochloride
# 16182
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16182_processed.png 20 Promethazine-Hydrochloride
# 16184
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16184_processed.png 20 Promethazine-Hydrochloride
# 16187
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16187_processed.png 20 Promethazine-Hydrochloride
# 16192
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16192_processed.png 20 Promethazine-Hydrochloride
# 16195
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16195_processed.png 20 Promethazine-Hydrochloride
# 16198
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16198_processed.png 20 Promethazine-Hydrochloride
# 16204
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16204_processed.png 20 Promethazine-Hydrochloride
# 16211
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16211_processed.png 50 Promethazine-Hydrochloride
# 16215
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16215_processed.png 50 Promethazine-Hydrochloride
# 16220
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16220_processed.png 50 Promethazine-Hydrochloride
# 16222
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16222_processed.png 50 Promethazine-Hydrochloride
# 16223
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16223_processed.png 50 Promethazine-Hydrochloride
# 16224
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16224_processed.png 50 Promethazine-Hydrochloride
# 16227
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16227_processed.png 50 Promethazine-Hydrochloride
# 16236
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16236_processed.png 100 Ampicillin
# 16237
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16237_processed.png 100 Ampicillin
# 16245
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16245_processed.png 100 Ampicillin
# 16246
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16246_processed.png 100 Ampicillin
# 16252
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16252_processed.png 100 Ampicillin
# 16259
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16259_processed.png 100 Ampicillin
# 16265
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16265_processed.png 100 Ampicillin
# 16271
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16271_processed.png 100 Ampicillin
# 16275
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16275_processed.png 100 Ampicillin
# 16277
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16277_processed.png 100 Ampicillin
# 16281
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16281_processed.png 100 Ampicillin
# 16283
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16283_processed.png 100 Ampicillin
# 16285
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16285_processed.png 100 Ampicillin
# 16289
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16289_processed.png 100 Ampicillin
# 16292
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16292_processed.png 100 Ampicillin
# 16294
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16294_processed.png 100 Ampicillin
# 16302
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16302_processed.png 80 Ampicillin
# 16303
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16303_processed.png 100 Ampicillin
# 16309
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16309_processed.png 100 Ampicillin
# 16314
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16314_processed.png 80 Ampicillin
# 16315
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16315_processed.png 80 Ampicillin
# 16318
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16318_processed.png 80 Ampicillin
# 16319
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16319_processed.png 80 Ampicillin
# 16324
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16324_processed.png 80 Ampicillin
# 16330
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16330_processed.png 80 Ampicillin
# 16351
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16351_processed.png 80 Ampicillin
# 16355
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16355_processed.png 80 Ampicillin
# 16359
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16359_processed.png 80 Ampicillin
# 16370
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16370_processed.png 50 Ampicillin
# 16380
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16380_processed.png 50 Ampicillin
# 16385
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16385_processed.png 50 Ampicillin
# 16389
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16389_processed.png 50 Ampicillin
# 16390
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16390_processed.png 50 Ampicillin
# 16404
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16404_processed.png 50 Ampicillin
# 16407
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16407_processed.png 50 Ampicillin
# 16408
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16408_processed.png 50 Ampicillin
# 16414
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16414_processed.png 50 Ampicillin
# 16420
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16420_processed.png 50 Ampicillin
# 16421
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16421_processed.png 50 Ampicillin
# 16434
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16434_processed.png 20 Ampicillin
# 16447
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16447_processed.png 20 Ampicillin
# 16454
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16454_processed.png 20 Ampicillin
# 16455
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16455_processed.png 20 Ampicillin
# 16456
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16456_processed.png 20 Ampicillin
# 16462
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16462_processed.png 20 Ampicillin
# 16465
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16465_processed.png 20 Ampicillin
# 16466
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16466_processed.png 20 Ampicillin
# 16467
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16467_processed.png 20 Ampicillin
# 16468
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16468_processed.png 20 Ampicillin
# 16473
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16473_processed.png 20 Ampicillin
# 16483
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16483_processed.png 20 Ampicillin
# 16491
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16491_processed.png 100 Albendazole
# 16492
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16492_processed.png 100 Albendazole
# 16493
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16493_processed.png 100 Albendazole
# 16497
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16497_processed.png 100 Albendazole
# 16498
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16498_processed.png 100 Albendazole
# 16504
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16504_processed.png 100 Albendazole
# 16506
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16506_processed.png 100 Albendazole
# 16514
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16514_processed.png 100 Albendazole
# 16515
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16515_processed.png 100 Albendazole
# 16519
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16519_processed.png 100 Albendazole
# 16530
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16530_processed.png 100 Albendazole
# 16536
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16536_processed.png 100 Albendazole
# 16538
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16538_processed.png 100 Albendazole
# 16541
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16541_processed.png 80 Albendazole
# 16546
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16546_processed.png 80 Albendazole
# 16554
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16554_processed.png 80 Albendazole
# 16555
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16555_processed.png 80 Albendazole
# 16558
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16558_processed.png 80 Albendazole
# 16567
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16567_processed.png 80 Albendazole
# 16571
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16571_processed.png 80 Albendazole
# 16572
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16572_processed.png 80 Albendazole
# 16574
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16574_processed.png 80 Albendazole
# 16577
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16577_processed.png 80 Albendazole
# 16579
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16579_processed.png 80 Albendazole
# 16581
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16581_processed.png 80 Albendazole
# 16583
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16583_processed.png 80 Albendazole
# 16588
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16588_processed.png 80 Albendazole
# 16594
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16594_processed.png 80 Albendazole
# 16595
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16595_processed.png 80 Albendazole
# 16596
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16596_processed.png 80 Albendazole
# 16601
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16601_processed.png 50 Albendazole
# 16604
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16604_processed.png 50 Albendazole
# 16605
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16605_processed.png 50 Albendazole
# 16606
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16606_processed.png 50 Albendazole
# 16608
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16608_processed.png 50 Albendazole
# 16615
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16615_processed.png 50 Albendazole
# 16616
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16616_processed.png 50 Albendazole
# 16623
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16623_processed.png 50 Albendazole
# 16627
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16627_processed.png 50 Albendazole
# 16629
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16629_processed.png 50 Albendazole
# 16630
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16630_processed.png 50 Albendazole
# 16631
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16631_processed.png 50 Albendazole
# 16632
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16632_processed.png 50 Albendazole
# 16647
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16647_processed.png 50 Albendazole
# 16648
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16648_processed.png 50 Albendazole
# 16650
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16650_processed.png 100 Ciprofloxacin
# 16657
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16657_processed.png 100 Ciprofloxacin
# 16659
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16659_processed.png 100 Ciprofloxacin
# 16665
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16665_processed.png 100 Ciprofloxacin
# 16669
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16669_processed.png 100 Ciprofloxacin
# 16670
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16670_processed.png 100 Ciprofloxacin
# 16673
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16673_processed.png 100 Ciprofloxacin
# 16678
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16678_processed.png 100 Ciprofloxacin
# 16680
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16680_processed.png 100 Ciprofloxacin
# 16683
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16683_processed.png 100 Ciprofloxacin
# 16685
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16685_processed.png 100 Ciprofloxacin
# 16686
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16686_processed.png 100 Ciprofloxacin
# 16692
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16692_processed.png 100 Ciprofloxacin
# 16696
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16696_processed.png 100 Ciprofloxacin
# 16698
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16698_processed.png 100 Ciprofloxacin
# 16702
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16702_processed.png 100 Ciprofloxacin
# 16713
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16713_processed.png 80 Ciprofloxacin
# 16714
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16714_processed.png 80 Ciprofloxacin
# 16727
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16727_processed.png 80 Ciprofloxacin
# 16736
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16736_processed.png 80 Ciprofloxacin
# 16741
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16741_processed.png 80 Ciprofloxacin
# 16745
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16745_processed.png 80 Ciprofloxacin
# 16747
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16747_processed.png 80 Ciprofloxacin
# 16749
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16749_processed.png 80 Ciprofloxacin
# 16752
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16752_processed.png 80 Ciprofloxacin
# 16756
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16756_processed.png 80 Ciprofloxacin
# 16758
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16758_processed.png 80 Ciprofloxacin
# 16761
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16761_processed.png 80 Ciprofloxacin
# 16762
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16762_processed.png 100 Ciprofloxacin
# 16764
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16764_processed.png 80 Ciprofloxacin
# 16772
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16772_processed.png 50 Ciprofloxacin
# 16778
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16778_processed.png 50 Ciprofloxacin
# 16782
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16782_processed.png 50 Ciprofloxacin
# 16784
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16784_processed.png 50 Ciprofloxacin
# 16786
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16786_processed.png 20 Albendazole
# 16796
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16796_processed.png 50 Ciprofloxacin
# 16798
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16798_processed.png 50 Ciprofloxacin
# 16806
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16806_processed.png 50 Ciprofloxacin
# 16812
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16812_processed.png 50 Ciprofloxacin
# 16819
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16819_processed.png 80 Ciprofloxacin
# 16820
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16820_processed.png 100 Ciprofloxacin
# 16822
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16822_processed.png 100 Ciprofloxacin
# 16830
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16830_processed.png 20 Albendazole
# 16836
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16836_processed.png 100 Ciprofloxacin
# 16850
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16850_processed.png 100 Ciprofloxacin
# 16856
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16856_processed.png 100 Ciprofloxacin
# 16862
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16862_processed.png 50 Ciprofloxacin
# 16863
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16863_processed.png 50 Ciprofloxacin
# 16866
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16866_processed.png 20 Ciprofloxacin
# 16867
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16867_processed.png 50 Ciprofloxacin
# 16868
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16868_processed.png 20 Ciprofloxacin
# 16870
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16870_processed.png 20 Ciprofloxacin
# 16871
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16871_processed.png 20 Ciprofloxacin
# 16873
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16873_processed.png 50 Ciprofloxacin
# 16878
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16878_processed.png 20 Ciprofloxacin
# 16880
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16880_processed.png 20 Ciprofloxacin
# 16882
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16882_processed.png 80 Ciprofloxacin
# 16888
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16888_processed.png 20 Ciprofloxacin
# 16889
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16889_processed.png 20 Ciprofloxacin
# 16895
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16895_processed.png 20 Albendazole
# 16901
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16901_processed.png 100 Ciprofloxacin
# 16906
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16906_processed.png 100 Ciprofloxacin
# 16909
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16909_processed.png 20 Albendazole
# 16914
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16914_processed.png 100 Ciprofloxacin
# 16919
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16919_processed.png 100 Ciprofloxacin
# 16922
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16922_processed.png 20 Albendazole
# 16924
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16924_processed.png 80 Ciprofloxacin
# 16926
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16926_processed.png 50 Ciprofloxacin
# 16927
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16927_processed.png 100 Ciprofloxacin
# 16946
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16946_processed.png 20 Albendazole
# 16954
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16954_processed.png 100 Ciprofloxacin
# 16960
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16960_processed.png 20 Albendazole
# 16966
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16966_processed.png 20 Ciprofloxacin
# 16968
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16968_processed.png 20 Ciprofloxacin
# 16970
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16970_processed.png 20 Ciprofloxacin
# 16971
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16971_processed.png 20 Ciprofloxacin
# 16974
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16974_processed.png 20 Ciprofloxacin
# 16976
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16976_processed.png 20 Ciprofloxacin
# 16978
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/16978_processed.png 20 Ciprofloxacin
# 16984
# ...
# 24838
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24838_processed.png 100 Azithromycin
# 24839
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24839_processed.png 20 Azithromycin
# 24843
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24843_processed.png 100 Azithromycin
# 24846
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24846_processed.png 20 Azithromycin
# 24854
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24854_processed.png 50 Azithromycin
# 24862
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24862_processed.png 50 Azithromycin
# 24866
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24866_processed.png 20 Azithromycin
# 24867
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24867_processed.png 80 Azithromycin
# 24868
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24868_processed.png 20 Azithromycin
# 24871
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24871_processed.png 100 Azithromycin
# 24874
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24874_processed.png 20 Azithromycin
# 24875
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24875_processed.png 20 Azithromycin
# 24880
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24880_processed.png 50 Azithromycin
# 24882
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24882_processed.png 80 Azithromycin
# 24892
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24892_processed.png 20 Azithromycin
# 24901
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24901_processed.png 80 Azithromycin
# 24902
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24902_processed.png 20 Azithromycin
# 24907
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24907_processed.png 100 Azithromycin
# 24912
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24912_processed.png 100 Azithromycin
# 24925
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24925_processed.png 20 Azithromycin
# 24933
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24933_processed.png 20 Azithromycin
# 24934
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24934_processed.png 80 Azithromycin
# 24935
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24935_processed.png 80 Azithromycin
# 24940
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24940_processed.png 50 Azithromycin
# 24943
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24943_processed.png 80 Azithromycin
# 24944
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24944_processed.png 20 Azithromycin
# 24947
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24947_processed.png 100 Azithromycin
# 24950
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24950_processed.png 100 Azithromycin
# 24953
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24953_processed.png 80 Azithromycin
# 24956
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24956_processed.png 100 Azithromycin
# 24964
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24964_processed.png 50 Azithromycin
# 24965
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24965_processed.png 20 Azithromycin
# 24966
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24966_processed.png 50 Azithromycin
# 24972
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24972_processed.png 80 Azithromycin
# 24975
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24975_processed.png 100 Azithromycin
# 24977
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24977_processed.png 100 Azithromycin
# 24984
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24984_processed.png 20 Azithromycin
# 24989
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24989_processed.png 80 Azithromycin
# 25192
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25192_processed.png 50 Ripe
# 25197
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25197_processed.png 80 Ripe
# 25199
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25199_processed.png 80 Ripe
# 25201
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25201_processed.png 100 Ripe
# 25205
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25205_processed.png 80 Ripe
# 25209
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25209_processed.png 100 Ripe
# 25215
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25215_processed.png 80 Ripe
# 25220
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25220_processed.png 80 Ripe
# 25221
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25221_processed.png 50 Ripe
# 25225
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25225_processed.png 100 Ripe
# 25238
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25238_processed.png 80 Ripe
# 25239
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25239_processed.png 80 Ripe
# 25246
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25246_processed.png 100 Ripe
# 25251
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25251_processed.png 100 Ripe
# 25252
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25252_processed.png 100 Ripe
# 25255
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25255_processed.png 50 Ripe
# 25257
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25257_processed.png 80 Ripe
# 25276
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25276_processed.png 100 Ripe
# 25277
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25277_processed.png 50 Ripe
# 25279
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25279_processed.png 80 Ripe
# 25282
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25282_processed.png 100 Ripe
# 25286
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25286_processed.png 80 Ripe
# 25288
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25288_processed.png 50 Ripe
# 25290
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25290_processed.png 50 Ripe
# 25291
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25291_processed.png 100 Ripe
# 25292
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25292_processed.png 100 Ripe
# 25293
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25293_processed.png 80 Ripe
# 25294
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25294_processed.png 100 Ripe
# 25298
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25298_processed.png 80 Ripe
# 25299
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25299_processed.png 100 Ripe
# 25305
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25305_processed.png 50 Ripe
# 25306
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25306_processed.png 80 Ripe
# 25308
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25308_processed.png 80 Ripe
# 25313
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25313_processed.png 100 Ripe
# 25323
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25323_processed.png 50 Ripe
# 25325
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25325_processed.png 20 Ripe
# 25327
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25327_processed.png 20 Ripe
# 25330
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25330_processed.png 50 Ripe
# 25331
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25331_processed.png 20 Ripe
# 25338
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25338_processed.png 100 Ripe
# 25344
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25344_processed.png 80 Ripe
# 25346
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25346_processed.png 80 Ripe
# 25353
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25353_processed.png 50 Ripe
# 25359
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25359_processed.png 50 Ripe
# 25363
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25363_processed.png 20 Ripe
# 25364
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25364_processed.png 20 Ripe
# 25370
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25370_processed.png 100 Ripe
# 25371
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25371_processed.png 80 Ripe
# 25372
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25372_processed.png 100 Ripe
# 25373
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25373_processed.png 50 Ripe
# 25384
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25384_processed.png 80 Ripe
# 25412
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25412_processed.png 20 Ripe
# 25413
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25413_processed.png 50 Ripe
# 25416
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25416_processed.png 50 Ripe
# 25417
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25417_processed.png 20 Ripe
# 25420
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25420_processed.png 20 Ripe
# 25430
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25430_processed.png 50 Ripe
# 25434
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25434_processed.png 50 Ripe
# 25435
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25435_processed.png 20 Ripe
# 25440
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25440_processed.png 50 Ripe
# 25441
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25441_processed.png 50 Ripe
# 25443
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25443_processed.png 50 Ripe
# 25446
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25446_processed.png 20 Ripe
# 25448
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25448_processed.png 80 Ripe
# 25452
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25452_processed.png 20 Ripe
# 25453
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25453_processed.png 100 Ripe
# 25455
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25455_processed.png 100 Ripe
# 25462
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25462_processed.png 80 Ripe
# 25463
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25463_processed.png 20 Ripe
# 25469
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25469_processed.png 80 Ripe
# 25473
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25473_processed.png 20 Ripe
# 25474
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25474_processed.png 100 Ripe
# 25478
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25478_processed.png 20 Ripe
# 25486
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25486_processed.png 20 Ripe
# 25490
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25490_processed.png 80 Ripe
# 25492
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25492_processed.png 50 Ripe
# 25494
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25494_processed.png 20 Ripe
# 25495
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25495_processed.png 50 Ripe
# 25496
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25496_processed.png 20 Ripe
# 25503
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25503_processed.png 20 Ripe
# 25507
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25507_processed.png 80 Ripe
# 25508
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25508_processed.png 50 Ripe
# 25510
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25510_processed.png 80 Ripe
# 25515
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25515_processed.png 100 Ripe
# 25518
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25518_processed.png 100 Ripe
# 25521
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25521_processed.png 80 Ripe
# 25522
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25522_processed.png 50 Ripe
# 25535
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25535_processed.png 20 Ripe
# 25542
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25542_processed.png 50 Ripe
# 25546
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25546_processed.png 100 Ripe
# 25550
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25550_processed.png 100 Ripe
# 25572
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25572_processed.png 20 Ripe
# 25577
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25577_processed.png 100 Ripe
# 25578
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25578_processed.png 20 Ripe
# 25579
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25579_processed.png 20 Ripe
# 25581
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25581_processed.png 20 Ripe
# 25588
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25588_processed.png 50 Ripe
# 25595
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25595_processed.png 20 Ripe
# 25605
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25605_processed.png 100 Ripe
# 25609
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25609_processed.png 80 Ripe
# 25612
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25612_processed.png 20 Ripe
# 25614
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25614_processed.png 20 Ripe
# 25616
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25616_processed.png 50 Ripe
# 25617
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25617_processed.png 100 Ripe
# 25620
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25620_processed.png 100 Ripe
# 25625
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25625_processed.png 20 Ripe
# 25632
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25632_processed.png 80 Ripe
# 25637
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25637_processed.png 50 Ripe
# 25638
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25638_processed.png 20 Ripe
# 25642
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25642_processed.png 50 Ripe
# 25646
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25646_processed.png 80 Ripe
# 25834
# https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25834_processed.png 100 Hydroxychloroquine

# %%
results_nn_nnan.sample(20)
# Out:
#          id  sample_id                actual_class  actual_quantity  \
# 8081  23837      52173                  rifampicin              100
# 3831  19186      52941                tetracycline              100
# 1059  16319      53633                  ampicillin               80
# 4400  19777      52317            sulfamethoxazole               50
# 2487  17747      53197           benzyl-penicillin               20
# 5887  21481      51728          hydroxychloroquine               20
# 5812  21356      53464          hydroxychloroquine               80
# 5163  20547      53766                 chloroquine               50
# 8396  24152      55249                pyrazinamide              100
# 2809  18069      52500                   isoniazid               20
# 922   16182      53557  promethazine-hydrochloride               20
# 920   16180      53557  promethazine-hydrochloride               20
# 7519  23275      51896             ferrous-sulfate              100
# 425   15672      53464          hydroxychloroquine               80
# 9494  25452      55489                        ripe               20
# 944   16204      53534  promethazine-hydrochloride               20
# 8188  23944      55457                  rifampicin               20
# 1281  16541      53422                 albendazole               80
# 658   15916      53016          hydroxychloroquine               50
# 7219  22975      51935                  ethambutol               20
#
#      nn_pred_quantity nn_pred_prob nn_pred_energy                 nn_pred_api  \
# 8081              100     0.999959      -1.938544                  Rifampicin
# 3831              100     0.998657       -0.40182                Tetracycline
# 1059               80     0.694882       -7.27409                  Ampicillin
# 4400               80     0.964744       -2.43039            Sulfamethoxazole
# 2487              100      0.56084      -5.272242           Benzyl-Penicillin
# 5887               20     0.999953      -1.096698          Hydroxychloroquine
# 5812              100     0.919126      -6.025324          Hydroxychloroquine
# 5163               50     0.835173      -4.985154                 Chloroquine
# 8396              100     0.999995       2.375662                Pyrazinamide
# 2809               20     0.873763      -3.885047                   Isoniazid
# 922                20     0.880343      -2.678282  Promethazine-Hydrochloride
# 920                20     0.992727      -2.288234  Promethazine-Hydrochloride
# 7519               80     0.811491       -5.13393             Ferrous-Sulfate
# 425               100     0.929797      -3.980072          Hydroxychloroquine
# 9494               20      0.99964      -0.533508                        Ripe
# 944                50     0.746948      -5.083766  Promethazine-Hydrochloride
# 8188               20     0.994897      -2.068565                  Rifampicin
# 1281               20     0.948192      -4.467238                 Albendazole
# 658                50      0.57598      -6.821961          Hydroxychloroquine
# 7219               20     0.927088      -2.133779                  Ethambutol
#
#      nn_pred_api_prob nn_pred_api_energy
# 8081         0.999895          17.210686
# 3831         0.997708          14.575552
# 1059         0.999969          15.729166
# 4400         0.997993          12.322608
# 2487         0.997928          11.912428
# 5887         0.998516          13.276796
# 5812         0.999481          14.819748
# 5163         0.999555          15.386755
# 8396         0.999845          15.607238
# 2809         0.999682          15.736484
# 922          0.987643          13.017518
# 920          0.993341          13.464387
# 7519         0.998419          12.895237
# 425          0.998619          14.655503
# 9494         0.999907          16.634995
# 944          0.999657          15.623514
# 8188         0.996918          14.954376
# 1281         0.994915          13.577479
# 658          0.999041          15.222167
# 7219         0.999353          12.343709

# %%
df.sample_name.unique()
# Out:
# array(['chloroquine', 'doxycycline', 'isoniazid', 'amoxicillin',
#        'unknown', 'hydroxychloroquine', 'ripe',
#        'promethazine-hydrochloride', 'ampicillin', 'albendazole',
#        'ciprofloxacin', 'lactose', 'ascorbic-acid', 'calcium-carbonate',
#        'starch-(maize)', 'benzyl-penicillin', 'tetracycline',
#        'ceftriaxone', 'sulfamethoxazole', 'epinephrine', 'ethambutol',
#        'ferrous-sulfate', 'rifampicin', 'pyrazinamide', 'azithromycin',
#        'doxorubicin-(powder-or-tablets)'], dtype=object)

# %%
df[df.sample_name == 'starch-(maize)']
# Out:
#          id     sample_name           test_name                 user_name  \
# 1971  17231  starch-(maize)  12LanePADKenya2015           Marya Lieberman
# 1972  17232  starch-(maize)  12LanePADKenya2015           Marya Lieberman
# 1973  17233  starch-(maize)  12LanePADKenya2015                   PAD Blu
# 1974  17234  starch-(maize)  12LanePADKenya2015                   PAD Blu
# 1976  17236  starch-(maize)  12LanePADKenya2015                   PAD Blu
# ...     ...             ...                 ...                       ...
# 3375  18705  starch-(maize)  12LanePADKenya2015  api-OUDPXFH17PEGKUW3FM4Z
# 3376  18706  starch-(maize)  12LanePADKenya2015  api-OUDPXFH17PEGKUW3FM4Z
# 3378  18708  starch-(maize)  12LanePADKenya2015  api-OUDPXFH17PEGKUW3FM4Z
# 3385  18715  starch-(maize)  12LanePADKenya2015  api-OUDPXFH17PEGKUW3FM4Z
# 3386  18716  starch-(maize)  12LanePADKenya2015  api-OUDPXFH17PEGKUW3FM4Z
#
#          date_of_creation                                 picture_1_location  \
# 1971  2020-05-27T11:50:04  /var/www/html/images/padimages/raw/10000/17231...
# 1972  2020-05-27T11:50:06  /var/www/html/images/padimages/raw/10000/17232...
# 1973  2020-05-27T11:55:04  /var/www/html/images/padimages/raw/10000/17233...
# 1974  2020-05-27T11:55:06  /var/www/html/images/padimages/raw/10000/17234...
# 1976  2020-05-27T11:55:10  /var/www/html/images/padimages/raw/10000/17236...
# ...                   ...                                                ...
# 3375  2020-06-04T09:18:02  /var/www/html/images/padimages/raw/10000/18705...
# 3376  2020-06-04T09:18:05  /var/www/html/images/padimages/raw/10000/18706...
# 3378  2020-06-04T09:18:08  /var/www/html/images/padimages/raw/10000/18708...
# 3385  2020-06-04T09:18:38  /var/www/html/images/padimages/raw/10000/18715...
# 3386  2020-06-04T09:18:41  /var/www/html/images/padimages/raw/10000/18716...
#
#                                 processed_file_location      processing_date  \
# 1971  /var/www/html/images/padimages/processed/10000...  2020-05-27T11:50:04
# 1972  /var/www/html/images/padimages/processed/10000...  2020-05-27T11:50:06
# 1973  /var/www/html/images/padimages/processed/10000...  2020-05-27T11:55:04
# 1974  /var/www/html/images/padimages/processed/10000...  2020-05-27T11:55:06
# 1976  /var/www/html/images/padimages/processed/10000...  2020-05-27T11:55:10
# ...                                                 ...                  ...
# 3375  /var/www/html/images/padimages/processed/10000...  2020-06-04T09:18:02
# 3376  /var/www/html/images/padimages/processed/10000...  2020-06-04T09:18:05
# 3378  /var/www/html/images/padimages/processed/10000...  2020-06-04T09:18:08
# 3385  /var/www/html/images/padimages/processed/10000...  2020-06-04T09:18:38
# 3386  /var/www/html/images/padimages/processed/10000...  2020-06-04T09:18:41
#
#         camera_type_1                                              notes  \
# 1971  Google Pixel 3a  emailed rectified pad image. batch=n/a, quanti...
# 1972  Google Pixel 3a  emailed rectified pad image. batch=n/a, quanti...
# 1973    BLU BLU R1 HD  emailed rectified pad image. batch=n/a, quanti...
# 1974    BLU BLU R1 HD  emailed rectified pad image. batch=n/a, quanti...
# 1976    BLU BLU R1 HD  emailed rectified pad image. batch=n/a, quanti...
# ...               ...                                                ...
# 3375    BLU BLU R1 HD                        batch=n/a, quantity=100%, b
# 3376    BLU BLU R1 HD                        batch=n/a, quantity=100%, b
# 3378    BLU BLU R1 HD                        batch=n/a, quantity=100%, b
# 3385    BLU BLU R1 HD                        batch=n/a, quantity=100%, b
# 3386    BLU BLU R1 HD                        batch=n/a, quantity=100%, b
#
#      category  sample_id  quantity
# 1971  FHI2020      52405       100
# 1972  FHI2020      52400       100
# 1973  FHI2020      52404       100
# 1974  FHI2020      52401       100
# 1976  FHI2020      52399       100
# ...       ...        ...       ...
# 3375  FHI2020      52377       100
# 3376  FHI2020      52382       100
# 3378  FHI2020      52381       100
# 3385  FHI2020      52383       100
# 3386  FHI2020      52381       100
#
# [133 rows x 13 columns]

# %%
results_nn_nnan.to_csv('../data/final_results__nn-all.csv', index=False)
